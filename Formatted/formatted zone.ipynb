# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import duckdb
import glob
import time
import os
import pandas as pd

# %%
#Creating a connection to the duck db database:
conn = duckdb.connect()
# set correct working directory
os.chdir('/content/drive/MyDrive/Project ADSDB Max_Julian/landing/persistent')

# %%
worldometer_v1 = conn.execute("""SELECT * FROM read_csv_auto('worldometer_data_v1_2023-09-25 16:24:46.csv')""").df()
worldometer_v2 = conn.execute("""SELECT * FROM read_csv_auto('worldometer_data_v2_2023-10-06 16:13:05.csv')""").df()
owid_v1 = conn.execute("""SELECT * FROM read_csv_auto('owid-covid-data_v1_2023-09-25 16:24:46.csv')""").df()
owid_v2 = conn.execute("""SELECT * FROM read_csv_auto('owid-covid-data_v2_2023-10-06 16:13:05.csv')""").df()
